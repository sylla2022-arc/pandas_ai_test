# %% [markdown]
# ## Installation des dependances

# %%
# !pip install --upgrade pandas pandasai
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# ...
#      --------------------------------------- 10.7/10.7 MB 19.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 797.7/797.7 kB 16.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.6/7.6 MB 15.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# ...
#      ------------------------------------- 385.8/385.8 kB 12.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 160.2/160.2 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.20
#     Uninstalling prompt-toolkit-3.0.20:
#       Successfully uninstalled prompt-toolkit-3.0.20
# ...

# %% [markdown]
# ##  Importation des dependances

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI

# %% [markdown]
# ## Création de datafame pour test

# %%
df = pd.DataFrame({
    "Pays": ["États-Unis", "royaume-Uni", "France", "Allemagne", "Italie", "Espagne", "Canada", "Australie", "Japon", "Chine"],
    "PIB": [21400000, 2940000, 2830000, 3870000, 2160000, 1350000, 1780000, 1320000, 516000, 14000000],
    "Indice du bonheur": [7.3, 7.2, 6.5, 7.0, 6.0, 6.3, 7.3, 7.3, 5.9, 5.0]
})

# %%
df.head(3)
# Out:
#           Pays       PIB  Indice du bonheur
# 0   États-Unis  21400000                7.3
# 1  royaume-Uni   2940000                7.2
# 2       France   2830000                6.5

# %% [markdown]
# ## Aller sur
# https://github.com/gventuri/pandas-ai/blob/main/Notebooks/Getting%20Started.ipynb concernant la création de votre clé API. J'ai caché la mienne.

# %%
key_openAI = "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"
llm = OpenAI(api_token=key_openAI)

# %% [markdown]
# ## Interrogation de pandas AI
#
# Nous allons interroger pandasAI de nous génèrer des graphiques à partir de simple consigne en français.

# %%
pandas_ai  = PandasAI(llm)
pandas_ai.run(df, prompt = 'Quels sont les 5 pays les moins heureux ?')
# Out:
# "Les 5 pays les moins heureux sont la Chine, le Japon, l'Italie, l'Espagne et la France."

# %%
pandas_ai.run(df, prompt = 'Tracer le diagramme circulaire des pays en indiquant pour chacun leur pib, en utlisant des couleurs différentes, séparer les parts avec des ombres, afficher la légende à droite en haut, tracer une copie du diagramme à droite en incluant que les 5 les pays heureux, le tout en format normal ', )
# Out:
# "Sure, I can help you with that! To create a pie chart of the countries, we'll use different colors to represent their GDP. We'll also add shadows to separate the sections and place the legend at the top right corner. Then, we'll make a copy of the chart on the right side, including only the top 5 happiest countries. We'll keep the format normal. Does that sound good?"

# %% [markdown]
# ## Références :
#
# * **1.**   https://colab.research.google.com/drive/1J1riIqbuLBQAFsRhWlf6L99fwB5J6-bj?usp=sharing&utm_source=brevo&utm_campaign=2%20Pandas%20AI%20-%20Le%20futur%20de%20lanalyse%20de%20donnes&utm_medium=email#scrollTo=MhByl8oxEJFH
#
#
#
# * **2.**  https://github.com/gventuri/pandas-ai
